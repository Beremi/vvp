# %% [markdown]
# # 1. Debugování (ladění) v Pythonu
#
# Po funkcích a řízení toku je dobré umět kód systematicky ladit.
# V Pythonu lze ladit například přes `pdb` nebo pomocí *IPython debuggeru* `%debug`.
#
# V této části se zaměříme na ladění ve VS Code, protože je přehledné a praktické v prostředí Jupyter notebooků.

# %% [markdown]
# ## 1.1 Breakpointy
#
# Spusťte následující kód. Záměrně skončí na nezachycené chybě.
#
# Postup:
# 1. Klikněte vlevo od čísla řádku a nastavte breakpoint (červená tečka).
# 2. Spusťte buňku v debug režimu (menu u tlačítka Play nebo `Alt+Ctrl+Shift+Enter`).
# 3. Program se zastaví na breakpointu a otevře se panel Debug.
#
# V panelu sledujte hodnoty proměnných, Call Stack i seznam breakpointů.
#
# Základní ovládání:
# - Continue - `F5`
# - Step Over - `F10`
# - Step Into - `F11`
# - Step Out - `Shift+F11`
# - Stop - `Shift+F5`
#
# V `Debug Console` můžete spouštět Python kód v aktuálním stavu programu.

# %%
def divide_numbers(a, b):
    c = a / b
    return c

divide_numbers(1, 0)

# %% [markdown]
# Breakpointy jsou aktivní při každém spuštění v debug režimu.
# Platí to i pro breakpointy nastavené v jiné buňce nebo v jiném souboru.

# %%
divide_numbers(1, 0)

# %% [markdown]
# ## 1.2 Speciální typy breakpointů ve VS Code
#
# Kromě běžných breakpointů můžete použít i pokročilé varianty:
# - Exception Breakpoint - zastaví program při vyvolání výjimky
# - Breakpoint Hit Count - zastaví program až po daném počtu průchodů řádkem
# - Conditional Breakpoint - zastaví program jen při splnění podmínky
# - Logpoint - vypíše zadaný text a hodnoty bez zastavení programu
